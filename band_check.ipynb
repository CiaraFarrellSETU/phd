# %% [markdown]
# <a href="https://colab.research.google.com/github/CiaraFarrellSETU/phd/blob/main/band_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rasterio

# %%
import rasterio

with rasterio.open('/content/loughbally_ortho.tif') as src:
    print("Number of bands:", src.count)
    print("Band descriptions:", src.descriptions)   #If the metadata doesn’t include names, you’ll just get None for each band.
# Out:
# Number of bands: 3
# Band descriptions: (None, None, None)

# %%
import rasterio

with rasterio.open('/content/Loughbally_Winter_RGB.tif') as src:
    print("Number of bands:", src.count)
    print("Band descriptions:", src.descriptions)
# Out:
# Number of bands: 3
# Band descriptions: (None, None, None)
